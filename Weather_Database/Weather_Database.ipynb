# %% [markdown]
# # Deliverable 1

# %% [markdown]
# Create a new set of 2,000 random latitudes and longitudes.

# %%
# Import the random module.
import random

# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. Unpacking the zip object above
coordinates = list(lat_lngs)

# %%
# import the citypy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Import the requests library
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8094f7fd4cf83856e02dd9562b63d4de

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | darnah
# Processing Record 2 of Set 1 | chifeng
# Processing Record 3 of Set 1 | okhotsk
# Processing Record 4 of Set 1 | vila franca do campo
# Processing Record 5 of Set 1 | guanica
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | guangyuan
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | lebyazhye
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | vao
# Processing Record 17 of Set 1 | omboue
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | macklin
# Processing Record 23 of Set 1 | kruisfontein
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | ostrovnoy
# Processing Record 26 of Set 1 | swellendam
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | te karaka
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | karratha
# Processing Record 35 of Set 1 | tuatapere
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | kochevo
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | derzhavinsk
# Processing Record 42 of Set 1 | aransas pass
# Processing Record 43 of Set 1 | hilliard
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | nanortalik
# Processing Record 46 of Set 1 | poum
# Processing Record 47 of Set 1 | mehamn
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | brigantine
# Processing Record 50 of Set 1 | ahuimanu
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | ulcinj
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 2 | charters towers
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | baghdad
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | guerrero negro
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | kirakira
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | inongo
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 2 | manapparai
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | airai
# Processing Record 24 of Set 2 | hasaki
# Processing Record 25 of Set 2 | usak
# Processing Record 26 of Set 2 | norman wells
# Processing Record 27 of Set 2 | caririacu
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | jiazi
# Processing Record 30 of Set 2 | punta arenas
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | kieta
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | arroyo
# Processing Record 35 of Set 2 | ulladulla
# Processing Record 36 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | chapais
# Processing Record 40 of Set 2 | hillsborough
# Processing Record 41 of Set 2 | acarau
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | lagoa
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | marawi
# Processing Record 47 of Set 2 | yuxia
# Processing Record 48 of Set 2 | luderitz
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | mount gambier
# Processing Record 2 of Set 3 | koumac
# Processing Record 3 of Set 3 | cabedelo
# Processing Record 4 of Set 3 | ribnica
# Processing Record 5 of Set 3 | sept-iles
# Processing Record 6 of Set 3 | tungor
# Processing Record 7 of Set 3 | cidreira
# Processing Record 8 of Set 3 | omsk
# Processing Record 9 of Set 3 | tabory
# Processing Record 10 of Set 3 | rio gallegos
# Processing Record 11 of Set 3 | calabozo
# Processing Record 12 of Set 3 | vilshofen
# Processing Record 13 of Set 3 | victoria
# Processing Record 14 of Set 3 | mataura
# Processing Record 15 of Set 3 | ler
# Processing Record 16 of Set 3 | nioro
# Processing Record 17 of Set 3 | curvelo
# Processing Record 18 of Set 3 | vestmanna
# Processing Record 19 of Set 3 | hokitika
# Processing Record 20 of Set 3 | padang
# Processing Record 21 of Set 3 | nishihara
# Processing Record 22 of Set 3 | sorland
# Processing Record 23 of Set 3 | merauke
# Processing Record 24 of Set 3 | khonsa
# Processing Record 25 of Set 3 | penhold
# Processing Record 26 of Set 3 | kapaa
# Processing Record 27 of Set 3 | pochutla
# Processing Record 28 of Set 3 | aykhal
# Processing Record 29 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 3 | port macquarie
# Processing Record 31 of Set 3 | tadine
# Processing Record 32 of Set 3 | itarema
# Processing Record 33 of Set 3 | portland
# Processing Record 34 of Set 3 | namatanai
# Processing Record 35 of Set 3 | leningradskiy
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | takoradi
# Processing Record 38 of Set 3 | saint george
# Processing Record 39 of Set 3 | nome
# Processing Record 40 of Set 3 | coolum beach
# Processing Record 41 of Set 3 | bell ville
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | hurricane
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | askiz
# Processing Record 46 of Set 3 | qaanaaq
# Processing Record 47 of Set 3 | mogadishu
# Processing Record 48 of Set 3 | ahipara
# Processing Record 49 of Set 3 | cabo san lucas
# Processing Record 50 of Set 3 | rocha
# Processing Record 1 of Set 4 | boyolangu
# Processing Record 2 of Set 4 | leshukonskoye
# Processing Record 3 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | sussex
# Processing Record 6 of Set 4 | shimoda
# Processing Record 7 of Set 4 | staryy nadym
# Processing Record 8 of Set 4 | zhigansk
# Processing Record 9 of Set 4 | semporna
# Processing Record 10 of Set 4 | hellvik
# Processing Record 11 of Set 4 | jingdezhen
# Processing Record 12 of Set 4 | moroni
# Processing Record 13 of Set 4 | turinsk
# Processing Record 14 of Set 4 | fairbanks
# Processing Record 15 of Set 4 | gejiu
# Processing Record 16 of Set 4 | houma
# Processing Record 17 of Set 4 | bereda
# Processing Record 18 of Set 4 | cap malheureux
# Processing Record 19 of Set 4 | pangody
# Processing Record 20 of Set 4 | houston
# Processing Record 21 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 22 of Set 4 | trimbak
# Processing Record 23 of Set 4 | constitucion
# Processing Record 24 of Set 4 | pergamino
# Processing Record 25 of Set 4 | arica
# Processing Record 26 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | provideniya
# Processing Record 29 of Set 4 | waipawa
# Processing Record 30 of Set 4 | wyndham
# Processing Record 31 of Set 4 | east london
# Processing Record 32 of Set 4 | saryozek
# Processing Record 33 of Set 4 | bonavista
# Processing Record 34 of Set 4 | katakwi
# Processing Record 35 of Set 4 | bambous virieux
# Processing Record 36 of Set 4 | kununurra
# Processing Record 37 of Set 4 | puerto del rosario
# Processing Record 38 of Set 4 | puerto baquerizo moreno
# Processing Record 39 of Set 4 | blackwater
# Processing Record 40 of Set 4 | veracruz
# Processing Record 41 of Set 4 | sao gabriel da cachoeira
# Processing Record 42 of Set 4 | yantal
# Processing Record 43 of Set 4 | barstow
# Processing Record 44 of Set 4 | cape town
# Processing Record 45 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 4 | birin
# Processing Record 47 of Set 4 | southbridge
# Processing Record 48 of Set 4 | ukiah
# Processing Record 49 of Set 4 | presidente medici
# Processing Record 50 of Set 4 | touros
# Processing Record 1 of Set 5 | pisco
# Processing Record 2 of Set 5 | grieskirchen
# Processing Record 3 of Set 5 | evensk
# Processing Record 4 of Set 5 | ribeira grande
# Processing Record 5 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 6 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 5 | zhuzhou
# Processing Record 8 of Set 5 | kuytun
# Processing Record 9 of Set 5 | suao
# City not found. Skipping...
# Processing Record 10 of Set 5 | namibe
# Processing Record 11 of Set 5 | bousso
# Processing Record 12 of Set 5 | san patricio
# Processing Record 13 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 5 | hamilton
# Processing Record 15 of Set 5 | tautira
# Processing Record 16 of Set 5 | chegdomyn
# Processing Record 17 of Set 5 | talnakh
# Processing Record 18 of Set 5 | fondi
# Processing Record 19 of Set 5 | coquimbo
# Processing Record 20 of Set 5 | san borja
# Processing Record 21 of Set 5 | puerto ayora
# Processing Record 22 of Set 5 | verkhnevilyuysk
# Processing Record 23 of Set 5 | salamiyah
# Processing Record 24 of Set 5 | mamallapuram
# Processing Record 25 of Set 5 | khatanga
# Processing Record 26 of Set 5 | kupang
# Processing Record 27 of Set 5 | cherskiy
# Processing Record 28 of Set 5 | kungurtug
# Processing Record 29 of Set 5 | pevek
# Processing Record 30 of Set 5 | waddan
# Processing Record 31 of Set 5 | leh
# Processing Record 32 of Set 5 | pangnirtung
# Processing Record 33 of Set 5 | praia
# Processing Record 34 of Set 5 | ayan
# Processing Record 35 of Set 5 | nizhneangarsk
# Processing Record 36 of Set 5 | vanimo
# Processing Record 37 of Set 5 | barrow
# Processing Record 38 of Set 5 | tay ninh
# Processing Record 39 of Set 5 | burica
# City not found. Skipping...
# Processing Record 40 of Set 5 | elat
# Processing Record 41 of Set 5 | kamsack
# Processing Record 42 of Set 5 | rafai
# Processing Record 43 of Set 5 | buhovo
# Processing Record 44 of Set 5 | deputatskiy
# Processing Record 45 of Set 5 | harper
# Processing Record 46 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 47 of Set 5 | grande-riviere
# City not found. Skipping...
# Processing Record 48 of Set 5 | naze
# Processing Record 49 of Set 5 | sangar
# Processing Record 50 of Set 5 | manica
# Processing Record 1 of Set 6 | fraserburgh
# Processing Record 2 of Set 6 | korla
# Processing Record 3 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 6 | toamasina
# Processing Record 5 of Set 6 | buala
# Processing Record 6 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 6 | auki
# Processing Record 8 of Set 6 | cockburn town
# Processing Record 9 of Set 6 | viedma
# Processing Record 10 of Set 6 | mazara del vallo
# Processing Record 11 of Set 6 | bengkulu
# Processing Record 12 of Set 6 | malakal
# Processing Record 13 of Set 6 | neryungri
# Processing Record 14 of Set 6 | xunchang
# Processing Record 15 of Set 6 | anchorage
# Processing Record 16 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 6 | mahebourg
# Processing Record 19 of Set 6 | koungou
# Processing Record 20 of Set 6 | komsomolskiy
# Processing Record 21 of Set 6 | meulaboh
# Processing Record 22 of Set 6 | senanga
# Processing Record 23 of Set 6 | zyryanka
# Processing Record 24 of Set 6 | fayaoue
# Processing Record 25 of Set 6 | dekoa
# City not found. Skipping...
# Processing Record 26 of Set 6 | honningsvag
# Processing Record 27 of Set 6 | goderich
# Processing Record 28 of Set 6 | chumikan
# Processing Record 29 of Set 6 | peniche
# Processing Record 30 of Set 6 | olinda
# Processing Record 31 of Set 6 | sindor
# Processing Record 32 of Set 6 | santa isabel
# Processing Record 33 of Set 6 | sankt valentin
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | svetlyy
# Processing Record 36 of Set 6 | etchoropo
# Processing Record 37 of Set 6 | ntungamo
# Processing Record 38 of Set 6 | kavieng
# Processing Record 39 of Set 6 | cururupu
# Processing Record 40 of Set 6 | simpsonville
# Processing Record 41 of Set 6 | samarai
# Processing Record 42 of Set 6 | kawalu
# Processing Record 43 of Set 6 | chipinge
# Processing Record 44 of Set 6 | buarcos
# Processing Record 45 of Set 6 | lavrentiya
# Processing Record 46 of Set 6 | kloulklubed
# Processing Record 47 of Set 6 | port hedland
# Processing Record 48 of Set 6 | braco do norte
# Processing Record 49 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 6 | chernyshevskiy
# Processing Record 1 of Set 7 | quatre cocos
# Processing Record 2 of Set 7 | san cristobal
# Processing Record 3 of Set 7 | mouila
# Processing Record 4 of Set 7 | karmana
# City not found. Skipping...
# Processing Record 5 of Set 7 | agadez
# Processing Record 6 of Set 7 | okandja
# City not found. Skipping...
# Processing Record 7 of Set 7 | bengbu
# Processing Record 8 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 7 | teguldet
# Processing Record 10 of Set 7 | ngunguru
# Processing Record 11 of Set 7 | baudh
# Processing Record 12 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 7 | axim
# Processing Record 14 of Set 7 | coos bay
# Processing Record 15 of Set 7 | chester
# Processing Record 16 of Set 7 | junin
# Processing Record 17 of Set 7 | bambanglipuro
# Processing Record 18 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 7 | katsuura
# Processing Record 20 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 7 | tchibanga
# Processing Record 22 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 7 | braganca
# Processing Record 24 of Set 7 | hovd
# Processing Record 25 of Set 7 | eston
# Processing Record 26 of Set 7 | jurm
# Processing Record 27 of Set 7 | vestmannaeyjar
# Processing Record 28 of Set 7 | nouadhibou
# Processing Record 29 of Set 7 | whitehorse
# Processing Record 30 of Set 7 | gambela
# Processing Record 31 of Set 7 | jalu
# Processing Record 32 of Set 7 | dauphin
# Processing Record 33 of Set 7 | fukue
# Processing Record 34 of Set 7 | baherden
# Processing Record 35 of Set 7 | solnechnyy
# Processing Record 36 of Set 7 | makakilo city
# Processing Record 37 of Set 7 | kushima
# Processing Record 38 of Set 7 | krasnoselkup
# Processing Record 39 of Set 7 | kahului
# Processing Record 40 of Set 7 | klaeng
# Processing Record 41 of Set 7 | richards bay
# Processing Record 42 of Set 7 | dunedin
# Processing Record 43 of Set 7 | svetlogorsk
# Processing Record 44 of Set 7 | dingle
# Processing Record 45 of Set 7 | locri
# Processing Record 46 of Set 7 | sur
# Processing Record 47 of Set 7 | nurota
# Processing Record 48 of Set 7 | akhmim
# Processing Record 49 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 50 of Set 7 | luwuk
# Processing Record 1 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 8 | mackay
# Processing Record 3 of Set 8 | tonj
# Processing Record 4 of Set 8 | bolshaya irba
# City not found. Skipping...
# Processing Record 5 of Set 8 | atambua
# Processing Record 6 of Set 8 | phan thiet
# Processing Record 7 of Set 8 | asau
# Processing Record 8 of Set 8 | hammerfest
# Processing Record 9 of Set 8 | russell
# Processing Record 10 of Set 8 | geraldton
# Processing Record 11 of Set 8 | boulder city
# Processing Record 12 of Set 8 | kaitangata
# Processing Record 13 of Set 8 | glubokoe
# City not found. Skipping...
# Processing Record 14 of Set 8 | grenfell
# Processing Record 15 of Set 8 | san anselmo
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | shirvan
# Processing Record 18 of Set 8 | santa maria
# Processing Record 19 of Set 8 | avera
# Processing Record 20 of Set 8 | karla
# Processing Record 21 of Set 8 | asilah
# Processing Record 22 of Set 8 | ancud
# Processing Record 23 of Set 8 | champerico
# Processing Record 24 of Set 8 | praia da vitoria
# Processing Record 25 of Set 8 | yumen
# Processing Record 26 of Set 8 | hualmay
# Processing Record 27 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 28 of Set 8 | neftekamsk
# Processing Record 29 of Set 8 | luis correia
# Processing Record 30 of Set 8 | novouzensk
# Processing Record 31 of Set 8 | sayat
# Processing Record 32 of Set 8 | gelemso
# Processing Record 33 of Set 8 | lingyuan
# Processing Record 34 of Set 8 | nuuk
# Processing Record 35 of Set 8 | empa
# City not found. Skipping...
# Processing Record 36 of Set 8 | bullhead city
# Processing Record 37 of Set 8 | saint anthony
# Processing Record 38 of Set 8 | nelson bay
# Processing Record 39 of Set 8 | saint-francois
# Processing Record 40 of Set 8 | gotsu
# Processing Record 41 of Set 8 | chiang khong
# Processing Record 42 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 8 | caravelas
# Processing Record 44 of Set 8 | grandview
# Processing Record 45 of Set 8 | vanavara
# Processing Record 46 of Set 8 | chimoio
# Processing Record 47 of Set 8 | kusu
# Processing Record 48 of Set 8 | muncar
# Processing Record 49 of Set 8 | porto walter
# Processing Record 50 of Set 8 | terdal
# Processing Record 1 of Set 9 | boueni
# Processing Record 2 of Set 9 | mecca
# Processing Record 3 of Set 9 | buluang
# Processing Record 4 of Set 9 | marsh harbour
# Processing Record 5 of Set 9 | kuyanovo
# Processing Record 6 of Set 9 | marsa matruh
# Processing Record 7 of Set 9 | opuwo
# Processing Record 8 of Set 9 | souillac
# Processing Record 9 of Set 9 | sulangan
# Processing Record 10 of Set 9 | jilib
# Processing Record 11 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 9 | faya
# Processing Record 13 of Set 9 | aizawl
# Processing Record 14 of Set 9 | aksay
# Processing Record 15 of Set 9 | sam chuk
# Processing Record 16 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 17 of Set 9 | rivadavia
# Processing Record 18 of Set 9 | kargasok
# Processing Record 19 of Set 9 | boralday
# Processing Record 20 of Set 9 | burjuc
# Processing Record 21 of Set 9 | gat
# Processing Record 22 of Set 9 | la ronge
# Processing Record 23 of Set 9 | fantino
# Processing Record 24 of Set 9 | mondeville
# Processing Record 25 of Set 9 | pouembout
# Processing Record 26 of Set 9 | sibolga
# Processing Record 27 of Set 9 | lakatoro
# Processing Record 28 of Set 9 | chokwe
# Processing Record 29 of Set 9 | sao joao da barra
# Processing Record 30 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 9 | porto santo
# Processing Record 32 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 33 of Set 9 | turukhansk
# Processing Record 34 of Set 9 | preobrazheniye
# Processing Record 35 of Set 9 | qaqortoq
# Processing Record 36 of Set 9 | hobyo
# Processing Record 37 of Set 9 | broome
# Processing Record 38 of Set 9 | sola
# Processing Record 39 of Set 9 | vigrestad
# Processing Record 40 of Set 9 | jining
# Processing Record 41 of Set 9 | clarence town
# Processing Record 42 of Set 9 | huarmey
# Processing Record 43 of Set 9 | madera
# Processing Record 44 of Set 9 | srednekolymsk
# Processing Record 45 of Set 9 | taoudenni
# Processing Record 46 of Set 9 | aklavik
# Processing Record 47 of Set 9 | alofi
# Processing Record 48 of Set 9 | noumea
# Processing Record 49 of Set 9 | maldonado
# Processing Record 50 of Set 9 | northam
# Processing Record 1 of Set 10 | cayenne
# Processing Record 2 of Set 10 | magan
# Processing Record 3 of Set 10 | dubbo
# Processing Record 4 of Set 10 | zaraza
# Processing Record 5 of Set 10 | tommot
# Processing Record 6 of Set 10 | bergen
# Processing Record 7 of Set 10 | huambo
# Processing Record 8 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 10 | laguna
# Processing Record 10 of Set 10 | bernay
# Processing Record 11 of Set 10 | katima mulilo
# Processing Record 12 of Set 10 | tessalit
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | havelock
# Processing Record 15 of Set 10 | kazanskoye
# Processing Record 16 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 10 | tezu
# Processing Record 18 of Set 10 | abonnema
# Processing Record 19 of Set 10 | rosa zarate
# Processing Record 20 of Set 10 | phonhong
# Processing Record 21 of Set 10 | baiquan
# Processing Record 22 of Set 10 | paamiut
# Processing Record 23 of Set 10 | half moon bay
# Processing Record 24 of Set 10 | porto nacional
# Processing Record 25 of Set 10 | robstown
# Processing Record 26 of Set 10 | puerto escondido
# Processing Record 27 of Set 10 | manicore
# Processing Record 28 of Set 10 | gondanglegi
# Processing Record 29 of Set 10 | fortuna
# Processing Record 30 of Set 10 | kleck
# City not found. Skipping...
# Processing Record 31 of Set 10 | bauchi
# Processing Record 32 of Set 10 | vila velha
# Processing Record 33 of Set 10 | torit
# Processing Record 34 of Set 10 | ballina
# Processing Record 35 of Set 10 | nhulunbuy
# Processing Record 36 of Set 10 | stara synyava
# Processing Record 37 of Set 10 | pacific grove
# Processing Record 38 of Set 10 | buta
# Processing Record 39 of Set 10 | edd
# Processing Record 40 of Set 10 | novoye atlashevo
# City not found. Skipping...
# Processing Record 41 of Set 10 | panaba
# Processing Record 42 of Set 10 | kyshtovka
# Processing Record 43 of Set 10 | bull savanna
# Processing Record 44 of Set 10 | port-gentil
# Processing Record 45 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 46 of Set 10 | sabzevar
# Processing Record 47 of Set 10 | berlevag
# Processing Record 48 of Set 10 | sinjai
# Processing Record 49 of Set 10 | xichang
# Processing Record 50 of Set 10 | xining
# Processing Record 1 of Set 11 | qobustan
# Processing Record 2 of Set 11 | ndende
# Processing Record 3 of Set 11 | seoul
# Processing Record 4 of Set 11 | bemidji
# Processing Record 5 of Set 11 | rincon
# Processing Record 6 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 11 | olafsvik
# Processing Record 8 of Set 11 | sarmanovo
# Processing Record 9 of Set 11 | montepuez
# Processing Record 10 of Set 11 | bandarbeyla
# Processing Record 11 of Set 11 | xacmaz
# Processing Record 12 of Set 11 | bilky
# Processing Record 13 of Set 11 | mazamari
# Processing Record 14 of Set 11 | lasa
# Processing Record 15 of Set 11 | nabire
# Processing Record 16 of Set 11 | nemuro
# Processing Record 17 of Set 11 | clyde river
# Processing Record 18 of Set 11 | abha
# Processing Record 19 of Set 11 | mount isa
# Processing Record 20 of Set 11 | batagay-alyta
# Processing Record 21 of Set 11 | canon city
# Processing Record 22 of Set 11 | filingue
# Processing Record 23 of Set 11 | bendigo
# Processing Record 24 of Set 11 | dalgopol
# Processing Record 25 of Set 11 | lac-megantic
# Processing Record 26 of Set 11 | ondangwa
# Processing Record 27 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 11 | alice springs
# Processing Record 29 of Set 11 | paredon
# Processing Record 30 of Set 11 | dongtai
# Processing Record 31 of Set 11 | jinxiang
# Processing Record 32 of Set 11 | zbarazh
# Processing Record 33 of Set 11 | kavaratti
# Processing Record 34 of Set 11 | mbanza-ngungu
# Processing Record 35 of Set 11 | gazanjyk
# Processing Record 36 of Set 11 | muros
# Processing Record 37 of Set 11 | bac lieu
# Processing Record 38 of Set 11 | margate
# Processing Record 39 of Set 11 | dongsheng
# Processing Record 40 of Set 11 | beyneu
# Processing Record 41 of Set 11 | narsaq
# Processing Record 42 of Set 11 | jatai
# Processing Record 43 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 11 | namie
# Processing Record 45 of Set 11 | henties bay
# Processing Record 46 of Set 11 | korem
# Processing Record 47 of Set 11 | parobe
# Processing Record 48 of Set 11 | belaya gora
# Processing Record 49 of Set 11 | oistins
# Processing Record 50 of Set 11 | puerto carreno
# Processing Record 1 of Set 12 | rogatica
# Processing Record 2 of Set 12 | ampanihy
# Processing Record 3 of Set 12 | hofn
# Processing Record 4 of Set 12 | klyuchi
# Processing Record 5 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 6 of Set 12 | porto novo
# Processing Record 7 of Set 12 | novoagansk
# Processing Record 8 of Set 12 | ponoka
# Processing Record 9 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 12 | egvekinot
# Processing Record 11 of Set 12 | khanpur
# Processing Record 12 of Set 12 | keti bandar
# Processing Record 13 of Set 12 | pathein
# Processing Record 14 of Set 12 | tigil
# Processing Record 15 of Set 12 | najran
# Processing Record 16 of Set 12 | polunochnoye
# Processing Record 17 of Set 12 | vuktyl
# Processing Record 18 of Set 12 | moose factory
# Processing Record 19 of Set 12 | wilmington
# Processing Record 20 of Set 12 | daru
# Processing Record 21 of Set 12 | villa de reyes
# Processing Record 22 of Set 12 | newcastle
# Processing Record 23 of Set 12 | brae
# Processing Record 24 of Set 12 | saint-augustin
# Processing Record 25 of Set 12 | perry
# Processing Record 26 of Set 12 | mahon
# Processing Record 27 of Set 12 | dwarka
# Processing Record 28 of Set 12 | seminole
# Processing Record 29 of Set 12 | katherine
# Processing Record 30 of Set 12 | masaka
# Processing Record 31 of Set 12 | havre-saint-pierre
# Processing Record 32 of Set 12 | vaasa
# Processing Record 33 of Set 12 | kibara
# Processing Record 34 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 12 | kiama
# Processing Record 36 of Set 12 | mpika
# Processing Record 37 of Set 12 | tevaitoa
# Processing Record 38 of Set 12 | iranshahr
# Processing Record 39 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 40 of Set 12 | port blair
# Processing Record 41 of Set 12 | tlapa
# City not found. Skipping...
# Processing Record 42 of Set 12 | parana
# Processing Record 43 of Set 12 | mahajanga
# Processing Record 44 of Set 12 | carnaiba
# Processing Record 45 of Set 12 | touho
# Processing Record 46 of Set 12 | rumonge
# Processing Record 47 of Set 12 | cortland
# Processing Record 48 of Set 12 | shingu
# Processing Record 49 of Set 12 | galdar
# Processing Record 50 of Set 12 | kalamata
# Processing Record 1 of Set 13 | san policarpo
# Processing Record 2 of Set 13 | novopokrovka
# Processing Record 3 of Set 13 | west bay
# Processing Record 4 of Set 13 | tabou
# Processing Record 5 of Set 13 | fayetteville
# Processing Record 6 of Set 13 | jumla
# Processing Record 7 of Set 13 | hvide sande
# Processing Record 8 of Set 13 | puerto colombia
# Processing Record 9 of Set 13 | angoche
# Processing Record 10 of Set 13 | celestun
# Processing Record 11 of Set 13 | salto
# Processing Record 12 of Set 13 | roald
# Processing Record 13 of Set 13 | beloha
# Processing Record 14 of Set 13 | maniitsoq
# Processing Record 15 of Set 13 | arlit
# Processing Record 16 of Set 13 | bacolod
# Processing Record 17 of Set 13 | uniao
# Processing Record 18 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 19 of Set 13 | itoman
# Processing Record 20 of Set 13 | benguela
# Processing Record 21 of Set 13 | senneterre
# Processing Record 22 of Set 13 | suslovo
# Processing Record 23 of Set 13 | vostok
# Processing Record 24 of Set 13 | oktyabrskiy
# Processing Record 25 of Set 13 | nara
# Processing Record 26 of Set 13 | lata
# Processing Record 27 of Set 13 | garowe
# Processing Record 28 of Set 13 | marshalltown
# Processing Record 29 of Set 13 | lahaina
# Processing Record 30 of Set 13 | yokadouma
# Processing Record 31 of Set 13 | stabat
# Processing Record 32 of Set 13 | emerald
# Processing Record 33 of Set 13 | matara
# Processing Record 34 of Set 13 | marienburg
# Processing Record 35 of Set 13 | thayetmyo
# Processing Record 36 of Set 13 | price
# Processing Record 37 of Set 13 | cooma
# Processing Record 38 of Set 13 | muroto
# Processing Record 39 of Set 13 | sarahan
# Processing Record 40 of Set 13 | pryozerne
# Processing Record 41 of Set 13 | veraval
# Processing Record 42 of Set 13 | benghazi
# Processing Record 43 of Set 13 | thinadhoo
# Processing Record 44 of Set 13 | san pedro
# Processing Record 45 of Set 13 | troitsko-pechorsk
# Processing Record 46 of Set 13 | willmar
# Processing Record 47 of Set 13 | melbu
# Processing Record 48 of Set 13 | homer
# Processing Record 49 of Set 13 | chuzhou
# Processing Record 50 of Set 13 | sulzbach-rosenberg
# Processing Record 1 of Set 14 | emba
# Processing Record 2 of Set 14 | bayan
# Processing Record 3 of Set 14 | santa marta de tormes
# Processing Record 4 of Set 14 | pagman
# City not found. Skipping...
# Processing Record 5 of Set 14 | manzil tamim
# City not found. Skipping...
# Processing Record 6 of Set 14 | byron bay
# Processing Record 7 of Set 14 | morehead
# Processing Record 8 of Set 14 | qena
# Processing Record 9 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 14 | bonga
# Processing Record 11 of Set 14 | college
# Processing Record 12 of Set 14 | myitkyina
# Processing Record 13 of Set 14 | eureka
# Processing Record 14 of Set 14 | mikkeli
# Processing Record 15 of Set 14 | madison
# Processing Record 16 of Set 14 | grass valley
# Processing Record 17 of Set 14 | yarmouth
# Processing Record 18 of Set 14 | acari
# Processing Record 19 of Set 14 | high river
# Processing Record 20 of Set 14 | hambantota
# Processing Record 21 of Set 14 | dhidhdhoo
# Processing Record 22 of Set 14 | ishigaki
# Processing Record 23 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 14 | lompoc
# Processing Record 25 of Set 14 | salalah
# Processing Record 26 of Set 14 | strathmore
# Processing Record 27 of Set 14 | talara
# Processing Record 28 of Set 14 | yen bai
# Processing Record 29 of Set 14 | sinegorye
# Processing Record 30 of Set 14 | rio cuarto
# Processing Record 31 of Set 14 | storforshei
# Processing Record 32 of Set 14 | killybegs
# Processing Record 33 of Set 14 | kaspiysk
# Processing Record 34 of Set 14 | arkhangelsk
# Processing Record 35 of Set 14 | isiro
# Processing Record 36 of Set 14 | mudkhed
# Processing Record 37 of Set 14 | trincomalee
# Processing Record 38 of Set 14 | coihaique
# Processing Record 39 of Set 14 | garissa
# Processing Record 40 of Set 14 | bodden town
# Processing Record 41 of Set 14 | chengmai
# City not found. Skipping...
# Processing Record 42 of Set 14 | la sarre
# Processing Record 43 of Set 14 | kazanka
# Processing Record 44 of Set 14 | wichian buri
# Processing Record 45 of Set 14 | lazaro cardenas
# Processing Record 46 of Set 14 | ponta delgada
# Processing Record 47 of Set 14 | codrington
# Processing Record 48 of Set 14 | navadwip
# Processing Record 49 of Set 14 | paulo afonso
# Processing Record 50 of Set 14 | baker city
# Processing Record 1 of Set 15 | churapcha
# Processing Record 2 of Set 15 | beya
# Processing Record 3 of Set 15 | aguimes
# Processing Record 4 of Set 15 | stepantsevo
# Processing Record 5 of Set 15 | puyang
# Processing Record 6 of Set 15 | qorveh
# Processing Record 7 of Set 15 | tilichiki
# Processing Record 8 of Set 15 | grand bank
# Processing Record 9 of Set 15 | keetmanshoop
# Processing Record 10 of Set 15 | ambilobe
# Processing Record 11 of Set 15 | rosario
# Processing Record 12 of Set 15 | bathsheba
# Processing Record 13 of Set 15 | mizoch
# Processing Record 14 of Set 15 | angoram
# Processing Record 15 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 15 | montevideo
# Processing Record 17 of Set 15 | fengrun
# Processing Record 18 of Set 15 | sisimiut
# Processing Record 19 of Set 15 | arawa
# Processing Record 20 of Set 15 | tsumeb
# Processing Record 21 of Set 15 | san quintin
# Processing Record 22 of Set 15 | safaga
# Processing Record 23 of Set 15 | snezhnogorsk
# Processing Record 24 of Set 15 | lubsko
# Processing Record 25 of Set 15 | paso de patria
# Processing Record 26 of Set 15 | mudgee
# Processing Record 27 of Set 15 | pyshchug
# Processing Record 28 of Set 15 | necochea
# Processing Record 29 of Set 15 | santa helena de goias
# Processing Record 30 of Set 15 | filadelfia
# Processing Record 31 of Set 15 | sioux lookout
# Processing Record 32 of Set 15 | warmbad
# Processing Record 33 of Set 15 | gazli
# Processing Record 34 of Set 15 | isangel
# Processing Record 35 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 15 | goya
# Processing Record 37 of Set 15 | rexburg
# Processing Record 38 of Set 15 | tanggu
# Processing Record 39 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 40 of Set 15 | guozhen
# Processing Record 41 of Set 15 | necocli
# Processing Record 42 of Set 15 | podgornoye
# Processing Record 43 of Set 15 | shaunavon
# Processing Record 44 of Set 15 | araguaina
# Processing Record 45 of Set 15 | buraydah
# Processing Record 46 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 15 | klaksvik
# Processing Record 48 of Set 15 | morro bay
# Processing Record 49 of Set 15 | port lincoln
# Processing Record 50 of Set 15 | goycay
# City not found. Skipping...
# Processing Record 1 of Set 16 | qafsah
# City not found. Skipping...
# Processing Record 2 of Set 16 | riverton
# Processing Record 3 of Set 16 | sao filipe
# Processing Record 4 of Set 16 | betanzos
# Processing Record 5 of Set 16 | murwillumbah
# Processing Record 6 of Set 16 | dolores
# Processing Record 7 of Set 16 | kadan
# Processing Record 8 of Set 16 | tura
# Processing Record 9 of Set 16 | lukang
# Processing Record 10 of Set 16 | saquena
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 691

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Darnah      LY  32.7670   22.6367     62.56        75
# 1                 Chifeng      CN  42.2683  118.9636     45.30        20
# 2                 Okhotsk      RU  59.3833  143.3000     31.98        92
# 3    Vila Franca Do Campo      PT  37.7167  -25.4333     64.81        74
# 4                 Guanica      PR  17.9716  -66.9080     81.61        93
# ..                    ...     ...      ...       ...       ...       ...
# 686               Dolores      AR -36.3132  -57.6792     55.29        54
# 687                 Kadan      CZ  50.3833   13.2667     55.18        74
# 688                  Tura      IN  25.5198   90.2201     67.89        92
# 689                Lukang      TW  24.0567  120.4352     72.07        82
# 690               Saquena      PE  -4.6667  -73.5167     83.26        78
#
#      Cloudiness  Wind Speed Current Description                 Date
# 0            92        8.86     overcast clouds  2022-04-30 19:28:51
# 1           100        7.83     overcast clouds  2022-04-30 19:28:51
# 2            44        6.24    scattered clouds  2022-04-30 19:28:52
# 3            14        4.70          few clouds  2022-04-30 19:28:52
# 4           100        9.69     overcast clouds  2022-04-30 19:28:53
# ..          ...         ...                 ...                  ...
# 686          89        5.88     overcast clouds  2022-04-30 19:49:54
# 687          93        2.55     overcast clouds  2022-04-30 19:49:55
# 688          61        3.36       broken clouds  2022-04-30 19:49:55
# 689         100       19.89     overcast clouds  2022-04-30 19:49:56
# 690          67        2.30       broken clouds  2022-04-30 19:49:57
#
# [691 rows x 10 columns]

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
